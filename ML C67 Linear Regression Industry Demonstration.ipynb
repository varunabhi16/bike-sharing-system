# %% [markdown]
# ### Steps
# - Importing necessary libries
# - Loading dataset
# - Understanding Problem Statement
# - Data Understanding
# - Missing Value check
# - EDA
# - PreProcessing - Dummy Creation
# - Train-Test Split
# - Feature Selection
# - Modeling
# - Train model

# %% [markdown]
# ## Importing Necessary libraries

# %%
# For data analysis and numerical function
import pandas as pd
import numpy as np

#for Virtulization 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
df = pd.read_csv(r"C:\Users\Varun\Upgrade_course_specific\Course 2\Module 1\data_housing.csv")

# %%
df.head(2)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
#
#    PTRATIO      B  LSTAT  Price
# 0     15.3  396.9   4.98   24.0
# 1     17.8  396.9   9.14   21.6

# %%
df.shape
# Out:
# (506, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
# Problem Statement: Train a linear regression model to predict the price of the house using given information

# %%
# :Attribute Information (in order): 
#     - CRIM per capita crime rate by town 
#     - ZN proportion of residential land zoned for lots over 25,000 sq.ft. 
#     - INDUS proportion of non-retail business acres per town 
#     - CHAS Charles River dummy variable (= 1 if tract bounds river; 0 otherwise) 
#     - NOX nitric oxides concentration (parts per 10 million) 
#     - RM average number of rooms per dwelling 
#     - AGE proportion of owner-occupied units built prior to 1940 
#     - DIS weighted distances to five Boston employment centres 
#     - RAD index of accessibility to radial highways 
#     - TAX full-value property-tax rate per  $10,000 
#     - PTRATIO pupil-teacher ratio by town 
#     - B 1000(Bk - 0.63)^2 where Bk is the proportion of black people by town 
#     - LSTAT % lower status of the population

# %% [markdown]
# ### Missing Value check

# %%
df.isnull().mean()
# Out:
# CRIM       0.0
# ZN         0.0
# INDUS      0.0
# CHAS       0.0
# NOX        0.0
# RM         0.0
# AGE        0.0
# DIS        0.0
# RAD        0.0
# TAX        0.0
# PTRATIO    0.0
# B          0.0
# LSTAT      0.0
# Price      0.0
# dtype: float64

# %%
# There are no missing values, but if there would have been any missing values
# we need to input or process them like we did or studied in EDA

# %%
df.nunique()
# Out:
# CRIM       504
# ZN          26
# INDUS       76
# CHAS         2
# NOX         81
# RM         446
# AGE        356
# DIS        412
# RAD          9
# TAX         66
# PTRATIO     46
# B          357
# LSTAT      455
# Price      229
# dtype: int64

# %%
num_cols=['CRIM','ZN','INDUS','NOX','RM','DIS','TAX','PTRATIO','B','LSTAT','Price']
cat_cols=['CHAS','RAD']

# %% [markdown]
# ### EDA

# %%
# Univariant Analysis
for i in num_cols:
    sns.histplot(x=df[i])
    plt.show()
for i in cat_cols:
    sns.countplot(x=df[i])
    plt.show()

# %%
# Bivariate Analysis
plt.figure(figsize=(6,6))
for i in num_cols:
    sns.scatterplot(x=df[i],y=df["Price"])
    plt.show()

# %%
# multivariate Analysis
plt.figure(figsize=(12,6))
sns.heatmap(df[num_cols].corr(),annot=True)
plt.show()

# %% [markdown]
# ### pre-processing Steps
# #### Dummy Variable creation  (One Hot Enccoding)

# %%
# Whenever we have more than 2 categories in categorical features, we need to create dumies for them

# %%
df[cat_cols].nunique()
# Out:
# CHAS    2
# RAD     9
# dtype: int64

# %%
df[cat_cols].head()
# Out:
#    CHAS  RAD
# 0   0.0  1.0
# 1   0.0  2.0
# 2   0.0  2.0
# 3   0.0  3.0
# 4   0.0  3.0

# %%
# Number of dummies = n-1
df1=pd.get_dummies(df,columns=["RAD"],drop_first=True,dtype=int)

# %%
df1.shape
# Out:
# (506, 21)

# %%
df["RAD"].unique()
# Out:
# array([ 1.,  2.,  3.,  5.,  4.,  8.,  6.,  7., 24.])

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'Price'],
#       dtype='object')

# %% [markdown]
# #### Train-Test split

# %%
X=df1.drop(["Price"],axis=1)
y=df1["Price"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=100)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (404, 20)
# (102, 20)

# %% [markdown]
# ### Scalaing

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)
x_test=scaler.transform(X_test) # As test data is unseen data we can't fit on it

# %%
X_train_df=pd.DataFrame(X_train,columns=X.columns)
X_test_df=pd.DataFrame(X_test,columns=X.columns)

# %%
X_train_df.head(2)
# Out:
#        CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0  1.892434 -0.495778  1.035280 -0.288288  1.019549 -0.074765  1.128863
# 1 -0.327672 -0.495778 -0.161802 -0.288288 -0.077387 -0.218185 -0.552953
#
#         DIS       TAX   PTRATIO         B     LSTAT   RAD_2.0   RAD_3.0  \
# 0 -1.175156  1.543468  0.813975  0.387891  1.262678 -0.203069 -0.293294
# 1 -0.561852 -0.600514 -0.039554  0.424998 -0.910043 -0.203069 -0.293294
#
#     RAD_4.0   RAD_5.0   RAD_6.0   RAD_7.0  RAD_8.0  RAD_24.0
# 0 -0.535373 -0.543021 -0.239983 -0.196368 -0.22215  1.709482
# 1  1.867857 -0.543021 -0.239983 -0.196368 -0.22215 -0.584972

# %% [markdown]
# ### Feature Selection

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
estimator=LinearRegression()
selector=RFE(estimator,n_features_to_select=8) #8-20

# %%
selector=selector.fit(X_train_df,y_train)
selector.support_
# Out:
# array([False,  True, False, False,  True,  True, False,  True,  True,
#         True, False,  True, False, False, False, False, False, False,
#        False,  True])

# %%
selected_features=X_train_df.columns[selector.support_]
print(selected_features)
# Out:
# Index(['ZN', 'NOX', 'RM', 'DIS', 'TAX', 'PTRATIO', 'LSTAT', 'RAD_24.0'], dtype='object')

# %%
X_train=X_train_df[selected_features]
X_test=X_test_df[selected_features]

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (404, 8)
# (102, 8)

# %% [markdown]
# ### Modeling

# %%
import statsmodels.api as sm

# %%
X_train_sm=sm.add_constant(X_train)#X_train_sm["const"]=1
X_test_sm=sm.add_constant(X_test)

# %%
model1=sm.OLS(np.array(y_train),X_train_sm)# Ordinary Least Squares
res1=model1.fit()
res1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.712
# Model:                            OLS   Adj. R-squared:                  0.706
# Method:                 Least Squares   F-statistic:                     122.1
# Date:                Thu, 24 Oct 2024   Prob (F-statistic):          7.99e-102
# Time:                        23:49:18   Log-Likelihood:                -1210.2
# No. Observations:                 404   AIC:                             2438.
# Df Residuals:                     395   BIC:                             2474.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         22.6210      0.243     92.912      0.000      22.142      23.100
# ...

# %%
# Acceptable Range for p-values is <0.05
# Acceptable Range for VIF is <=5

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_data=pd.DataFrame()
vif_data["Feature"]=X_train_sm.columns

vif_data["VIF"]=[variance_inflation_factor(X_train_sm.values,i) 
                 for i in range(len(X_train_sm.columns))]
vif_data
# Out:
#     Feature       VIF
# 0     const  1.000000
# 1        ZN  2.154506
# 2       NOX  3.758312
# 3        RM  1.850761
# 4       DIS  3.267930
# 5       TAX  6.622542
# 6   PTRATIO  1.734007
# 7     LSTAT  2.440413
# 8  RAD_24.0  5.744009

# %%
X_train_sm=X_train_sm.drop("TAX",axis=1)
X_test_sm=X_test_sm.drop("TAX",axis=1)

# %%
model2=sm.OLS(np.array(y_train),X_train_sm)# Ordinary Least Squares
res2=model2.fit()
res2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.705
# Model:                            OLS   Adj. R-squared:                  0.699
# Method:                 Least Squares   F-statistic:                     134.9
# Date:                Thu, 24 Oct 2024   Prob (F-statistic):          1.00e-100
# Time:                        23:49:46   Log-Likelihood:                -1215.4
# No. Observations:                 404   AIC:                             2447.
# Df Residuals:                     396   BIC:                             2479.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         22.6210      0.246     91.849      0.000      22.137      23.105
# ...

# %%
X_train_sm=X_train_sm.drop("RAD_24.0",axis=1)
X_test_sm=X_test_sm.drop("RAD_24.0",axis=1)

# %%
model3=sm.OLS(np.array(y_train),X_train_sm)# Ordinary Least Squares
res3=model3.fit()
res3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.704
# Model:                            OLS   Adj. R-squared:                  0.699
# Method:                 Least Squares   F-statistic:                     157.3
# Date:                Thu, 24 Oct 2024   Prob (F-statistic):          1.18e-101
# Time:                        23:49:59   Log-Likelihood:                -1215.8
# No. Observations:                 404   AIC:                             2446.
# Df Residuals:                     397   BIC:                             2474.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         22.6210      0.246     91.864      0.000      22.137      23.105
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_data=pd.DataFrame()
vif_data["Feature"]=X_train_sm.columns

vif_data["VIF"]=[variance_inflation_factor(X_train_sm.values,i) 
                 for i in range(len(X_train_sm.columns))]
vif_data
# Out:
#    Feature       VIF
# 0    const  1.000000
# 1       ZN  2.002172
# 2      NOX  2.842837
# 3       RM  1.789621
# 4      DIS  3.239984
# 5  PTRATIO  1.283293
# 6    LSTAT  2.393720

# %%
y_train_pred=res3.predict(X_train_sm)
y_test_pred=res3.predict(X_test_sm)

# %%
from sklearn.metrics import r2_score
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)
print("Train:",round(r2_train,3),"Test:",round(r2_test,3))
# Out:
# Train: 0.704 Test: -67.293

# %%
import nltk
import sklearn

print('The nltk version is {}.'.format(nltk.__version__))
print('The scikit-learn version is {}.'.format(plt.__version__))
# Out:
# The nltk version is 3.7.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17644\2666799103.py in <module>
#       3
#       4 print('The nltk version is {}.'.format(nltk.__version__))
# ----> 5 print('The scikit-learn version is {}.'.format(plt.__version__))
#
# AttributeError: module 'matplotlib.pyplot' has no attribute '__version__'

# %%
np
# Out:
# <module 'numpy' from 'C:\\Softwares\\python\\lib\\site-packages\\numpy\\__init__.py'>
